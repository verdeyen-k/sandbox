# %%
import pandas as pd

# %%
df = pd.read_csv('./power-to-choose-offers.csv')

# %%
df
# Out:
#                            [TduCompanyName]                [RepCompany]  \
# [idKey]
# 59               AEP TEXAS CENTRAL DIVISION                TEXPO ENERGY
# 60               AEP TEXAS CENTRAL DIVISION                TEXPO ENERGY
# 62               AEP TEXAS CENTRAL DIVISION                  TXU ENERGY
# 66               AEP TEXAS CENTRAL DIVISION                         YEP
# 68               AEP TEXAS CENTRAL DIVISION                         YEP
# 69               AEP TEXAS CENTRAL DIVISION                         YEP
# 618              AEP TEXAS CENTRAL DIVISION            NEC Co-op Energy
# 960              AEP TEXAS CENTRAL DIVISION                         YEP
# 971              AEP TEXAS CENTRAL DIVISION                         YEP
# 1306             AEP TEXAS CENTRAL DIVISION     SOUTHWEST POWER & LIGHT
# 1311             AEP TEXAS CENTRAL DIVISION     SOUTHWEST POWER & LIGHT
# 1433             AEP TEXAS CENTRAL DIVISION  AP GAS & ELECTRIC (TX) LLC
# ...

# %%
df = df.set_index('[idKey]')

# %%
a = set(df.loc[:,'[Fees/Credits]'])

# %%
b = [i.strip() for i in a]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-7baa6ac0ffed> in <module>()
# ----> 1 b = [i.strip() for i in a]
#
# <ipython-input-24-7baa6ac0ffed> in <listcomp>(.0)
# ----> 1 b = [i.strip() for i in a]
#
# AttributeError: 'float' object has no attribute 'strip'

# %%
for i in a:
    print(type(i), i)
# Out:
# <class 'float'> nan
# <class 'str'> $4.95 fee if usage is under 500 kWh in a billing period. $85.00 bill credit per billing cycle if your usage is greater than 999 and less than 1,501 kWh in a billing period. $40.00 bill credit per billing cycle if your usage is greater than 1,500 and less than 2,001 kWh in a billing period.
# <class 'str'> If your monthly usage is more than 999 kWh, you will receive a $80 bill credit.
#
#
# <class 'str'> $9.95 for usage less than 1,000 kW
# <class 'str'>  Lock in a low rate for 12 months -- and get a LuminAID solar lantern that can get you through almost any storm. Plus, we’ll donate a lantern in your name to an area in need. Includes an early termination fee of $175. To be eligible, customer must enroll in the “Prepare and Protect 12 Plan.” To receive LuminAID device, customer must maintain active Spark account in good standing (no past-due balance owed) for 45 days after beginning of service. May not be redeemed for cash.
# ...
